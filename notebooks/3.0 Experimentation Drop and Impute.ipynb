# %%
import numpy as np
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer, KNNImputer, MissingIndicator
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder, MinMaxScaler, PowerTransformer, OrdinalEncoder
from sklearn.model_selection import train_test_split
import mlflow

# %%
from sklearn import set_config
set_config(transform_output = "pandas")

# %%
pd.set_option('display.max_columns', 100)

# %%
data = pd.read_csv(("/Users/aryagupta/Desktop/food-delivery-estimation/food_time_prediction_using_mlops/data/interim/train_interim.csv"))
data.head()
# Out:
#    Unnamed: 0       id         person_id   age  ratings  restaurant_latitude  \
# 0           0  0x4607    INDORES13DEL02   37.0      4.9            22.745049
# 1           1  0xb379    BANGRES18DEL02   34.0      4.5            12.913041
# 2           2  0x5d6d    BANGRES19DEL01   23.0      4.4            12.914264
# 3           3  0x7a6a   COIMBRES13DEL02   38.0      4.7            11.003669
# 4           4  0x70a2    CHENRES12DEL01   32.0      4.6            12.972793
#
#    restaurant_longitude  delivery_latitude  delivery_longitude  order_date  \
# 0             75.892471          22.765049           75.912471  2022-03-19
# 1             77.683237          13.043041           77.813237  2022-03-25
# 2             77.678400          12.924264           77.688400  2022-03-19
# 3             76.976494          11.053669           77.026494  2022-04-05
# 4             80.249982          13.012793           80.289982  2022-03-26
#
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'id', 'person_id', 'age', 'ratings',
#        'restaurant_latitude', 'restaurant_longitude', 'delivery_latitude',
#        'delivery_longitude', 'order_date', 'order_time', 'order_picked',
#        'weather', 'traffic', 'vehicle_condition', 'order_type', 'vehical_type',
#        'multiple_deliveries', 'is_festival', 'city_category', 'time', 'city',
#        'day', 'month', 'year', 'day_of_week', 'is_weekend', 'order_time_hour',
#        'order_time_of_day', 'pickup_time', 'distance'],
#       dtype='object')

# %%
drop_feature = ['Unnamed: 0', 'id', 'person_id', 'restaurant_latitude', 'restaurant_longitude', 'delivery_latitude',
               'delivery_longitude', 'order_date', 'time', 'day', 'city', 'day_of_week', 'month', 'order_time', 
               'order_picked']

data.drop(drop_feature, axis = 1, inplace = True)

# %%
data.isna().sum()
# Out:
# age                    1854
# ratings                1908
# weather                 525
# traffic                 510
# vehicle_condition         0
# order_type                0
# vehical_type              0
# multiple_deliveries     993
# is_festival             228
# city_category          1198
# year                      0
# is_weekend                0
# order_time_hour        1640
# order_time_of_day         0
# pickup_time            1640
# distance               4029
# dtype: int64

# %%
# city_type	1198
time_taken	0
# is_weekend	0
# pickup_time_minutes	1640
order_time_of_day	2070
# distance	3630
distance_type	3630

# %%
data.sample(5)
# Out:
#         age  ratings weather  traffic  vehicle_condition order_type  \
# 28626  39.0      4.0  cloudy     jam                   1     snack
# 24648  26.0      5.0  stormy  medium                   1    drinks
# 23146  32.0      4.8   windy  medium                   1     snack
# 3550   27.0      4.6  cloudy     jam                   2    drinks
# 21517  30.0      4.7   sunny     jam                   1    buffet
#
#       vehical_type  multiple_deliveries is_festival   city_category  year  \
# 28626  motorcycle                   2.0         no   metropolitian   2022
# 24648  motorcycle                   1.0         no   metropolitian   2022
# 23146  motorcycle                   1.0         no   metropolitian   2022
# 3550      scooter                   2.0        yes   metropolitian   2022
# 21517  motorcycle                   0.0         no   metropolitian   2022
#
#        is_weekend  order_time_hour order_time_of_day  pickup_time   distance
# ...
